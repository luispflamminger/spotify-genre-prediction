# %%
import os
import json
import pandas as pd

# result.json contains flattened json (so list of dicts)
f = open(os.path.join(os.getcwd(), "..", "data_collection", "json", "flat_json_hiphop_rock_jazz.json"))
json_data = json.load(f)

# Convert list of dicts to dataframe
df = pd.DataFrame(json_data) 
df.head()
# Out:
#   category.id category.name    category.playlist.id category.playlist.name  \
# 0      hiphop       Hip Hop  37i9dQZF1DX0XUsuxWHRQd              RapCaviar
# 1      hiphop       Hip Hop  37i9dQZF1DX0XUsuxWHRQd              RapCaviar
# 2      hiphop       Hip Hop  37i9dQZF1DX0XUsuxWHRQd              RapCaviar
# 3      hiphop       Hip Hop  37i9dQZF1DX0XUsuxWHRQd              RapCaviar
# 4      hiphop       Hip Hop  37i9dQZF1DX0XUsuxWHRQd              RapCaviar
#
#   category.playlist.track.id                   category.playlist.track.name  \
# 0     2BcMwX1MPV6ZHP4tUT9uq6    Knife Talk (with 21 Savage ft. Project Pat)
# 1     3J4VKkUpLvomXJbn9ZAypO  Sharing Locations (feat. Lil Baby & Lil Durk)
# 2     7Bpx2vsWfQFBACRz4h3IqH              family ties (with Kendrick Lamar)
# 3     52nTQQahs46s1iHFQ3Wv5Q                                  Pissed Me Off
# 4     4KDNRh9Oor80z3XIxdWlui             Bubbly (with Drake & Travis Scott)
#
#   category.playlist.track.album.id  \
# 0           3SpBlxme9WbeQdI9kx7KAV
# 1           0q6qOUfC4ikWtv62KCnoip
# 2           3HqmX8hGcbbQZODgayNEYx
# 3           70m1QwzUoogjk2DDq1hA3b
# 4           7IKkHmEk4It4cRdOYanyvW
#
#               category.playlist.track.album.name  \
# 0                            Certified Lover Boy
# 1  Sharing Locations (feat. Lil Baby & Lil Durk)
# 2              family ties (with Kendrick Lamar)
# 3                                  Pissed Me Off
# 4                                           Punk
#
#     category.playlist.track.artist  \
# 0    Drake, 21 Savage, Project Pat
# 1    Meek Mill, Lil Durk, Lil Baby
# 2        Baby Keem, Kendrick Lamar
# 3                         Lil Durk
# 4  Young Thug, Drake, Travis Scott
#
#   category.playlist.track.feature.danceability  ...  \
# 0                                        0.849  ...
# 1                                        0.681  ...
# 2                                        0.711  ...
# 3                                        0.723  ...
# 4                                         0.91  ...
#
#   category.playlist.track.feature.loudness  \
# 0                                   -9.579
# 1                                   -5.585
# 2                                   -5.453
# 3                                  -10.707
# 4                                   -7.572
#
#   category.playlist.track.feature.mode  \
# 0                                    0
# 1                                    1
# 2                                    1
# 3                                    0
# 4                                    0
#
#   category.playlist.track.feature.speechiness  \
# 0                                       0.324
# 1                                      0.0385
# 2                                       0.329
# 3                                       0.485
# 4                                       0.257
#
#   category.playlist.track.feature.acousticness  \
# 0                                       0.0635
# 1                                      0.00383
# 2                                      0.00575
# 3                                      0.00311
# 4                                       0.0536
#
#   category.playlist.track.feature.instrumentalness  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                         1.26e-06
# 4                                                0
#
#   category.playlist.track.feature.liveness  \
# 0                                   0.0834
# 1                                    0.139
# 2                                    0.231
# 3                                    0.115
# 4                                    0.127
#
#   category.playlist.track.feature.valence  \
# 0                                   0.153
# 1                                   0.183
# 2                                   0.144
# 3                                   0.223
# 4                                   0.599
#
#   category.playlist.track.feature.tempo  \
# 0                               145.887
# 1                               151.951
# 2                                134.14
# 3                               155.967
# 4                               129.011
#
#   category.playlist.track.feature.duration_ms  \
# 0                                      242966
# 1                                      161053
# 2                                      252070
# 3                                      123077
# 4                                      165067
#
#   category.playlist.track.feature.time_signature
# 0                                              4
# 1                                              4
# 2                                              4
# 3                                              4
# 4                                              4
#
# [5 rows x 22 columns]

# %%
# Drop unneeded columns
columns_to_drop = [
    "category.name",
    "category.playlist.id",
    "category.playlist.name",
    "category.playlist.track.id",
    "category.playlist.track.album.id",
    "category.playlist.track.album.name",
    ]
df = df.drop(columns=columns_to_drop)

df = df.rename(columns={
    "category.id": "category",
    "category.playlist.track.name": "track",
    "category.playlist.track.artist": "artist",
    "category.playlist.track.feature.danceability": "feature_danceability",
    "category.playlist.track.feature.energy": "feature_energy",
    "category.playlist.track.feature.key": "feature_key",
    "category.playlist.track.feature.loudness": "feature_loudness",
    "category.playlist.track.feature.mode": "feature_mode",
    "category.playlist.track.feature.speechiness": "feature_speechiness",
    "category.playlist.track.feature.acousticness": "feature_acousticness",
    "category.playlist.track.feature.instrumentalness": "feature_instrumentalness",
    "category.playlist.track.feature.liveness": "feature_liveness",
    "category.playlist.track.feature.valence": "feature_valence",
    "category.playlist.track.feature.tempo": "feature_tempo",
    "category.playlist.track.feature.duration_ms": "feature_duration_ms",
    "category.playlist.track.feature.time_signature": "feature_time_signature"
})
df.head()
# Out:
#   category                                          track  \
# 0   hiphop    Knife Talk (with 21 Savage ft. Project Pat)
# 1   hiphop  Sharing Locations (feat. Lil Baby & Lil Durk)
# 2   hiphop              family ties (with Kendrick Lamar)
# 3   hiphop                                  Pissed Me Off
# 4   hiphop             Bubbly (with Drake & Travis Scott)
#
#                             artist feature_danceability feature_energy  \
# 0    Drake, 21 Savage, Project Pat                0.849          0.424
# 1    Meek Mill, Lil Durk, Lil Baby                0.681           0.63
# 2        Baby Keem, Kendrick Lamar                0.711          0.611
# 3                         Lil Durk                0.723          0.516
# 4  Young Thug, Drake, Travis Scott                 0.91          0.585
#
#   feature_key feature_loudness feature_mode feature_speechiness  \
# 0           5           -9.579            0               0.324
# 1           1           -5.585            1              0.0385
# 2           1           -5.453            1               0.329
# 3          11          -10.707            0               0.485
# 4          11           -7.572            0               0.257
#
#   feature_acousticness feature_instrumentalness feature_liveness  \
# 0               0.0635                        0           0.0834
# 1              0.00383                        0            0.139
# 2              0.00575                        0            0.231
# 3              0.00311                 1.26e-06            0.115
# 4               0.0536                        0            0.127
#
#   feature_valence feature_tempo feature_duration_ms feature_time_signature
# 0           0.153       145.887              242966                      4
# 1           0.183       151.951              161053                      4
# 2           0.144        134.14              252070                      4
# 3           0.223       155.967              123077                      4
# 4           0.599       129.011              165067                      4

# %%
df_plot = df

df_plot['feature_danceability']      = df_plot['feature_danceability'].astype(float)
df_plot['feature_energy']            = df_plot['feature_energy'].astype(float)
df_plot['feature_key']               = df_plot['feature_key'].astype(float)
df_plot['feature_loudness']          = df_plot['feature_loudness'].astype(float)
df_plot['feature_mode']              = df_plot['feature_mode'].astype(float)
df_plot['feature_speechiness']       = df_plot['feature_speechiness'].astype(float)
df_plot['feature_acousticness']      = df_plot['feature_acousticness'].astype(float)
df_plot['feature_instrumentalness']  = df_plot['feature_instrumentalness'].astype(float)
df_plot['feature_liveness']          = df_plot['feature_liveness'].astype(float)
df_plot['feature_valence']           = df_plot['feature_valence'].astype(float)
df_plot['feature_tempo']             = df_plot['feature_tempo'].astype(float)
df_plot['feature_duration_ms']       = df_plot['feature_duration_ms'].astype(float)
df_plot

df_plot.head()
# Out:
#   category                                          track  \
# 0   hiphop    Knife Talk (with 21 Savage ft. Project Pat)
# 1   hiphop  Sharing Locations (feat. Lil Baby & Lil Durk)
# 2   hiphop              family ties (with Kendrick Lamar)
# 3   hiphop                                  Pissed Me Off
# 4   hiphop             Bubbly (with Drake & Travis Scott)
#
#                             artist  feature_danceability  feature_energy  \
# 0    Drake, 21 Savage, Project Pat                 0.849           0.424
# 1    Meek Mill, Lil Durk, Lil Baby                 0.681           0.630
# 2        Baby Keem, Kendrick Lamar                 0.711           0.611
# 3                         Lil Durk                 0.723           0.516
# 4  Young Thug, Drake, Travis Scott                 0.910           0.585
#
#    feature_key  feature_loudness  feature_mode  feature_speechiness  \
# 0          5.0            -9.579           0.0               0.3240
# 1          1.0            -5.585           1.0               0.0385
# 2          1.0            -5.453           1.0               0.3290
# 3         11.0           -10.707           0.0               0.4850
# 4         11.0            -7.572           0.0               0.2570
#
#    feature_acousticness  feature_instrumentalness  feature_liveness  \
# 0               0.06350                  0.000000            0.0834
# 1               0.00383                  0.000000            0.1390
# 2               0.00575                  0.000000            0.2310
# 3               0.00311                  0.000001            0.1150
# 4               0.05360                  0.000000            0.1270
#
#    feature_valence  feature_tempo  feature_duration_ms feature_time_signature
# 0            0.153        145.887             242966.0                      4
# 1            0.183        151.951             161053.0                      4
# 2            0.144        134.140             252070.0                      4
# 3            0.223        155.967             123077.0                      4
# 4            0.599        129.011             165067.0                      4

# %%
df_hiphop   = df_plot.loc[df['category'] == 'hiphop']
df_jazz     = df_plot.loc[df['category'] == 'jazz']

# %%
filter  = df_hiphop["track"]=="The Real Slim Shady"
filter2 = df_hiphop["track"]=="Nonstop"
filter3 = df_hiphop["track"]=="Praise God"
filter4 = df_hiphop["track"]=="Rocket Ship"
filter5 = df_hiphop["track"]=="Motley Crew"

df_hiphop.where(filter , inplace = True)
#df_hiphop.where(filter2, inplace = True)
df_hiphop.dropna(subset = ['feature_danceability'], inplace=True)

df_hiphop

# Nonstop, The Real Slim Shady, Praise God, Rocket Ship, Motley Crew
# Out:
# /Users/martin/.pyenv/versions/3.8.10/envs/v3.8.10/lib/python3.8/site-packages/pandas/core/generic.py:9032: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._where(cond, other, inplace, axis, level, errors=errors)
# /Users/martin/.pyenv/versions/3.8.10/envs/v3.8.10/lib/python3.8/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#      category                track  artist  feature_danceability  \
# 1658   hiphop  The Real Slim Shady  Eminem                 0.949
#
#       feature_energy  feature_key  feature_loudness  feature_mode  \
# 1658           0.661          5.0            -4.244           0.0
#
#       feature_speechiness  feature_acousticness  feature_instrumentalness  \
# 1658               0.0572                0.0302                       0.0
#
#       feature_liveness  feature_valence  feature_tempo  feature_duration_ms  \
# 1658            0.0454             0.76        104.504             284200.0
#
#      feature_time_signature
# 1658                      4
