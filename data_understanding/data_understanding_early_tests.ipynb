# %%
import os
import json
import pandas as pd

# result.json contains flattened json (so list of dicts)
f = open(os.path.join(os.getcwd(), "..", "data_collection", "json", "flat_json_hiphop_rock_jazz.json"))
json_data = json.load(f)

# Convert list of dicts to dataframe
df = pd.DataFrame(json_data) 
df
# Out:
#       category.id category.name    category.playlist.id  \
# 0          hiphop       Hip Hop  37i9dQZF1DX0XUsuxWHRQd
# 1          hiphop       Hip Hop  37i9dQZF1DX0XUsuxWHRQd
# 2          hiphop       Hip Hop  37i9dQZF1DX0XUsuxWHRQd
# 3          hiphop       Hip Hop  37i9dQZF1DX0XUsuxWHRQd
# 4          hiphop       Hip Hop  37i9dQZF1DX0XUsuxWHRQd
# ...           ...           ...                     ...
# 18723        jazz          Jazz  37i9dQZF1DWYd2pXOke6Ag
# 18724        jazz          Jazz  37i9dQZF1DWYd2pXOke6Ag
# 18725        jazz          Jazz  37i9dQZF1DWYd2pXOke6Ag
# 18726        jazz          Jazz  37i9dQZF1DWYd2pXOke6Ag
# 18727        jazz          Jazz  37i9dQZF1DWYd2pXOke6Ag
#
#                      category.playlist.name category.playlist.track.id  \
# 0                                 RapCaviar     2BcMwX1MPV6ZHP4tUT9uq6
# 1                                 RapCaviar     3J4VKkUpLvomXJbn9ZAypO
# 2                                 RapCaviar     7Bpx2vsWfQFBACRz4h3IqH
# 3                                 RapCaviar     52nTQQahs46s1iHFQ3Wv5Q
# 4                                 RapCaviar     4KDNRh9Oor80z3XIxdWlui
# ...                                     ...                        ...
# 18723  Becoming presents: Kamasi Washington     34xTFwjPQ1dC6uJmleno7x
# 18724  Becoming presents: Kamasi Washington     6FIpyQeZ4caGR6V29kyYfy
# 18725  Becoming presents: Kamasi Washington     6jXAdaU4wshOAHXCUVvkn3
# 18726  Becoming presents: Kamasi Washington     2O9ufTJxuL5t3GVYQX6lSp
# 18727  Becoming presents: Kamasi Washington     5XV8y16vXJENfxa5bQH0LG
#
#                         category.playlist.track.name  \
# 0        Knife Talk (with 21 Savage ft. Project Pat)
# 1      Sharing Locations (feat. Lil Baby & Lil Durk)
# 2                  family ties (with Kendrick Lamar)
# 3                                      Pissed Me Off
# 4                 Bubbly (with Drake & Travis Scott)
# ...                                              ...
# 18723                                       Godspeed
# 18724                                  I Am Becoming
# 18725                                       Cherokee
# 18726                                  Southside V.1
# 18727                                          Truth
#
#       category.playlist.track.album.id  \
# 0               3SpBlxme9WbeQdI9kx7KAV
# 1               0q6qOUfC4ikWtv62KCnoip
# 2               3HqmX8hGcbbQZODgayNEYx
# 3               70m1QwzUoogjk2DDq1hA3b
# 4               7IKkHmEk4It4cRdOYanyvW
# ...                                ...
# 18723           3mH6qwIy9crq0I9YQbOuDf
# 18724           2ndDhPpR5sSsbtlJtsXCqi
# 18725           2j2q2ySuVk43eHB8wI5XQj
# 18726           2ndDhPpR5sSsbtlJtsXCqi
# 18727           0falRoEbZAuDn4lUoUzjmy
#
#                       category.playlist.track.album.name  \
# 0                                    Certified Lover Boy
# 1          Sharing Locations (feat. Lil Baby & Lil Durk)
# 2                      family ties (with Kendrick Lamar)
# 3                                          Pissed Me Off
# 4                                                   Punk
# ...                                                  ...
# 18723                                             Blonde
# 18724  Becoming (Music from the Netflix Original Docu...
# 18725                                           The Epic
# 18726  Becoming (Music from the Netflix Original Docu...
# 18727                                              Truth
#
#         category.playlist.track.artist  \
# 0        Drake, 21 Savage, Project Pat
# 1        Meek Mill, Lil Durk, Lil Baby
# 2            Baby Keem, Kendrick Lamar
# 3                             Lil Durk
# 4      Young Thug, Drake, Travis Scott
# ...                                ...
# 18723                      Frank Ocean
# 18724                Kamasi Washington
# 18725                Kamasi Washington
# 18726                Kamasi Washington
# 18727                Kamasi Washington
#
#       category.playlist.track.feature.danceability  ...  \
# 0                                            0.849  ...
# 1                                            0.681  ...
# 2                                            0.711  ...
# 3                                            0.723  ...
# 4                                             0.91  ...
# ...                                            ...  ...
# 18723                                        0.421  ...
# 18724                                        0.503  ...
# 18725                                        0.644  ...
# 18726                                        0.462  ...
# 18727                                        0.309  ...
#
#       category.playlist.track.feature.loudness  \
# 0                                       -9.579
# 1                                       -5.585
# 2                                       -5.453
# 3                                      -10.707
# 4                                       -7.572
# ...                                        ...
# 18723                                  -12.561
# 18724                                   -12.02
# 18725                                   -9.965
# 18726                                  -13.396
# 18727                                   -8.135
#
#       category.playlist.track.feature.mode  \
# 0                                        0
# 1                                        1
# 2                                        1
# 3                                        0
# 4                                        0
# ...                                    ...
# 18723                                    1
# 18724                                    1
# 18725                                    1
# 18726                                    1
# 18727                                    1
#
#       category.playlist.track.feature.speechiness  \
# 0                                           0.324
# 1                                          0.0385
# 2                                           0.329
# 3                                           0.485
# 4                                           0.257
# ...                                           ...
# 18723                                      0.0479
# 18724                                      0.0295
# 18725                                       0.117
# 18726                                      0.0586
# 18727                                       0.131
#
#       category.playlist.track.feature.acousticness  \
# 0                                           0.0635
# 1                                          0.00383
# 2                                          0.00575
# 3                                          0.00311
# 4                                           0.0536
# ...                                            ...
# 18723                                        0.931
# 18724                                       0.0412
# 18725                                        0.751
# 18726                                        0.665
# 18727                                        0.085
#
#       category.playlist.track.feature.instrumentalness  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                             1.26e-06
# 4                                                    0
# ...                                                ...
# 18723                                         0.000201
# 18724                                            0.922
# 18725                                            0.224
# 18726                                            0.946
# 18727                                            0.621
#
#       category.playlist.track.feature.liveness  \
# 0                                       0.0834
# 1                                        0.139
# 2                                        0.231
# 3                                        0.115
# 4                                        0.127
# ...                                        ...
# 18723                                    0.126
# 18724                                   0.0965
# 18725                                    0.107
# 18726                                    0.114
# 18727                                    0.143
#
#       category.playlist.track.feature.valence  \
# 0                                       0.153
# 1                                       0.183
# 2                                       0.144
# 3                                       0.223
# 4                                       0.599
# ...                                       ...
# 18723                                  0.0773
# 18724                                   0.489
# 18725                                   0.632
# 18726                                   0.426
# 18727                                   0.388
#
#       category.playlist.track.feature.tempo  \
# 0                                   145.887
# 1                                   151.951
# 2                                    134.14
# 3                                   155.967
# 4                                   129.011
# ...                                     ...
# 18723                               109.698
# 18724                               166.105
# 18725                                90.564
# 18726                               179.658
# 18727                               114.757
#
#       category.playlist.track.feature.duration_ms  \
# 0                                          242966
# 1                                          161053
# 2                                          252070
# 3                                          123077
# 4                                          165067
# ...                                           ...
# 18723                                      177922
# 18724                                      263447
# 18725                                      494467
# 18726                                       77190
# 18727                                      810322
#
#       category.playlist.track.feature.time_signature
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
# ...                                              ...
# 18723                                              4
# 18724                                              4
# 18725                                              4
# 18726                                              3
# 18727                                              4
#
# [18728 rows x 22 columns]

# %%
# Drop unneeded columns
columns_to_drop = [
    "category.name",
    "category.playlist.id",
    "category.playlist.name",
    "category.playlist.track.id",
    "category.playlist.track.name",
    "category.playlist.track.album.id",
    "category.playlist.track.album.name",
    "category.playlist.track.artist"
    ]
df = df.drop(columns=columns_to_drop)

df = df.rename(columns={
    "category.id": "category",
    "category.playlist.track.feature.danceability": "feature_danceability",
    "category.playlist.track.feature.energy": "feature_energy",
    "category.playlist.track.feature.key": "feature_key",
    "category.playlist.track.feature.loudness": "feature_loudness",
    "category.playlist.track.feature.mode": "feature_mode",
    "category.playlist.track.feature.speechiness": "feature_speechiness",
    "category.playlist.track.feature.acousticness": "feature_acousticness",
    "category.playlist.track.feature.instrumentalness": "feature_instrumentalness",
    "category.playlist.track.feature.liveness": "feature_liveness",
    "category.playlist.track.feature.valence": "feature_valence",
    "category.playlist.track.feature.tempo": "feature_tempo",
    "category.playlist.track.feature.duration_ms": "feature_duration_ms",
    "category.playlist.track.feature.time_signature": "feature_time_signature"
})
df
# Out:
#       category feature_danceability feature_energy feature_key  \
# 0       hiphop                0.849          0.424           5
# 1       hiphop                0.681           0.63           1
# 2       hiphop                0.711          0.611           1
# 3       hiphop                0.723          0.516          11
# 4       hiphop                 0.91          0.585          11
# ...        ...                  ...            ...         ...
# 18723     jazz                0.421         0.0952           6
# 18724     jazz                0.503          0.491           0
# 18725     jazz                0.644          0.594           5
# 18726     jazz                0.462          0.211           0
# 18727     jazz                0.309          0.837           2
#
#       feature_loudness feature_mode feature_speechiness feature_acousticness  \
# 0               -9.579            0               0.324               0.0635
# 1               -5.585            1              0.0385              0.00383
# 2               -5.453            1               0.329              0.00575
# 3              -10.707            0               0.485              0.00311
# 4               -7.572            0               0.257               0.0536
# ...                ...          ...                 ...                  ...
# 18723          -12.561            1              0.0479                0.931
# 18724           -12.02            1              0.0295               0.0412
# 18725           -9.965            1               0.117                0.751
# 18726          -13.396            1              0.0586                0.665
# 18727           -8.135            1               0.131                0.085
#
#       feature_instrumentalness feature_liveness feature_valence feature_tempo  \
# 0                            0           0.0834           0.153       145.887
# 1                            0            0.139           0.183       151.951
# 2                            0            0.231           0.144        134.14
# 3                     1.26e-06            0.115           0.223       155.967
# 4                            0            0.127           0.599       129.011
# ...                        ...              ...             ...           ...
# 18723                 0.000201            0.126          0.0773       109.698
# 18724                    0.922           0.0965           0.489       166.105
# 18725                    0.224            0.107           0.632        90.564
# 18726                    0.946            0.114           0.426       179.658
# 18727                    0.621            0.143           0.388       114.757
#
#       feature_duration_ms feature_time_signature
# 0                  242966                      4
# 1                  161053                      4
# 2                  252070                      4
# 3                  123077                      4
# 4                  165067                      4
# ...                   ...                    ...
# 18723              177922                      4
# 18724              263447                      4
# 18725              494467                      4
# 18726               77190                      3
# 18727              810322                      4
#
# [18728 rows x 14 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.arange(10)
data
plt.plot(data)

# %%
df.plot(kind='scatter', x='feature_time_signature', y='category')
plt.show()

# %%
df_hiphop = df.loc[df['category'] == 'hiphop']
df_jazz   = df.loc[df['category'] == 'jazz']
df_rock   = df.loc[df['category'] == 'rock']

df_jazz
# Out:
#       category feature_danceability feature_energy feature_key  \
# 13762     jazz                0.804          0.338          11
# 13763     jazz                0.329          0.724           1
# 13764     jazz                0.486            0.6           5
# 13765     jazz                0.671          0.457           1
# 13766     jazz                0.439          0.624          11
# ...        ...                  ...            ...         ...
# 18723     jazz                0.421         0.0952           6
# 18724     jazz                0.503          0.491           0
# 18725     jazz                0.644          0.594           5
# 18726     jazz                0.462          0.211           0
# 18727     jazz                0.309          0.837           2
#
#       feature_loudness feature_mode feature_speechiness feature_acousticness  \
# 13762           -9.532            0              0.0604                 0.63
# 13763           -7.327            0                0.04              0.00524
# 13764          -10.395            0               0.297                0.121
# 13765           -7.943            1              0.0312                0.383
# 13766           -8.255            0              0.0324                0.154
# ...                ...          ...                 ...                  ...
# 18723          -12.561            1              0.0479                0.931
# 18724           -12.02            1              0.0295               0.0412
# 18725           -9.965            1               0.117                0.751
# 18726          -13.396            1              0.0586                0.665
# 18727           -8.135            1               0.131                0.085
#
#       feature_instrumentalness feature_liveness feature_valence feature_tempo  \
# 13762                    0.834            0.108           0.446         85.01
# 13763                    0.853           0.0788          0.0465       135.889
# 13764                    0.108            0.131           0.886       187.981
# 13765                    0.525           0.0805           0.444       123.852
# 13766                   0.0211            0.763            0.33       123.352
# ...                        ...              ...             ...           ...
# 18723                 0.000201            0.126          0.0773       109.698
# 18724                    0.922           0.0965           0.489       166.105
# 18725                    0.224            0.107           0.632        90.564
# 18726                    0.946            0.114           0.426       179.658
# 18727                    0.621            0.143           0.388       114.757
#
#       feature_duration_ms feature_time_signature
# 13762              321547                      4
# 13763              312333                      4
# 13764              145643                      4
# 13765              335695                      4
# 13766              320687                      4
# ...                   ...                    ...
# 18723              177922                      4
# 18724              263447                      4
# 18725              494467                      4
# 18726               77190                      3
# 18727              810322                      4
#
# [4966 rows x 14 columns]

# %%
mu, sigma = 115, 15
x = mu + sigma * np.random.randn(10000)
fig, ax = plt.subplots(1, 2, figsize=(5, 2.7), layout='constrained')
# the histogram of the data
n, bins, patches = ax.hist(df_rock["feature_speechiness"], 1, density=100, facecolor='C0', alpha=0.75)

ax.set_xlabel('Songs')
#ax.set_ylabel('Probability')
ax.set_title('Loudness')
#ax.text(75, .025, r'$\mu=115,\ \sigma=15$')
#ax.axis([55, 175, 0, 0.03])
ax.grid(False)

len(df["feature_danceability"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/8l/bk7n5w8s3751wy49rg27zv1h0000gn/T/ipykernel_28507/163459910.py in <module>
#       3 fig, ax = plt.subplots(1, 2, figsize=(5, 2.7), layout='constrained')
#       4 # the histogram of the data
# ----> 5 n, bins, patches = ax.hist(df_rock["feature_speechiness"], 1, density=100, facecolor='C0', alpha=0.75)
#       6
#       7 ax.set_xlabel('Songs')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'hist'
